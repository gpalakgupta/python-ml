# %%
import requests
import bs4

# %%
print(bs4.__version__)
# Out:
# 4.13.4

# %%
simple_html_obj = """
<html>
    <head></head>
    <body>
        <div id = "div1">
            <p id = 1>Hello</p>
            <p id = 2>World</p>
            <p id = 3 shub = cb>hello</p>
        </div>
        <div id = "div2">
            <p id = 4 shub = cb>world</p>
            <p id = 4>hello</p>
        </div>
    </body>
</html>
"""

# %%
soup = bs4.BeautifulSoup(simple_html_obj)

# %%
print(soup.prettify())
# Out:
# <html>
#  <head>
#  </head>
#  <body>
#   <div id="div1">
#    <p id="1">
#     Hello
#    </p>
#    <p id="2">
#     World
#    </p>
#    <p id="3" shub="cb">
#     hello
#    </p>
#   </div>
#   <div id="div2">
#    <p id="4" shub="cb">
#     world
#    </p>
#    <p id="4">
#     hello
#    </p>
#   </div>
#  </body>
# </html>

# %%
para_tag = soup.find('div')

# %%
para_tag,type(para_tag)
# Out:
# (<div id="div1">
#  <p id="1">Hello</p>
#  <p id="2">World</p>
#  <p id="3" shub="cb">hello</p>
#  </div>,
#  bs4.element.Tag)

# %%
para_tag = soup.find('div',attrs={'id':'div2'})

# %%
para_tag,type(para_tag)
# Out:
# (<div id="div2">
#  <p id="4" shub="cb">world</p>
#  <p id="4">hello</p>
#  </div>,
#  bs4.element.Tag)

# %%
para_tag = soup.find('p',attrs={'shub':'cb'})
div_tag = soup.find('div')

# %%
para_tag,type(para_tag)
# Out:
# (<p id="3" shub="cb">hello</p>, bs4.element.Tag)

# %%
para_tag = soup.find_all('p',attrs={'shub':'cb'})

# %%
para_tag,type(para_tag)
# Out:
# ([<p id="3" shub="cb">hello</p>, <p id="4" shub="cb">world</p>],
#  bs4.element.ResultSet)

# %%
# para_tag.text
print(div_tag,div_tag.text)
# Out:
# <div id="div1">
# <p id="1">Hello</p>
# <p id="2">World</p>
# <p id="3" shub="cb">hello</p>
# </div>
# Hello
# World
# hello

# %%
para_tag.attrs
# Out:
# {'id': '3', 'shub': 'cb'}

# %%
para_tag.attrs['shub']
# Out:
# 'cb'

# %%
print(div_tag.find('p',attrs={'id':2}))
# Out:
# <p id="2">World</p>

# %%
para_tags = soup.find_all('p',attrs={'shub':'cb'})

# %%
para_tags
# Out:
# [<p id="3" shub="cb">hello</p>, <p id="4" shub="cb">world</p>]

# %%
for p_tag in para_tags:
    print(p_tag['id'],p_tag.text)
# Out:
# 3 hello
# 4 world

# %%
para_tag = soup.div

# %%
para_tag
# Out:
# <div id="div1">
# <p id="1">Hello</p>
# <p id="2">World</p>
# <p id="3" shub="cb">hello</p>
# </div>

# %%
type(para_tag)
# Out:
# bs4.element.Tag

# %%
div_tag = soup.find_all('div')

# %%
div_tag
# Out:
# [<div id="div1">
#  <p id="1">Hello</p>
#  <p id="2">World</p>
#  <p id="3" shub="cb">hello</p>
#  </div>,
#  <div id="div2">
#  <p id="4" shub="cb">world</p>
#  <p id="4">hello</p>
#  </div>]

# %%
len(div_tag)
# Out:
# 2

# %%
div_tag[0].p
# Out:
# <p id="1">Hello</p>

# %%
div_tag[0].find_all('p')
# Out:
# [<p id="1">Hello</p>, <p id="2">World</p>, <p id="3" shub="cb">hello</p>]

# %%
res  = requests.get('https://webscraper.io/test-sites/tables')

# %%
res
# Out:
# <Response [200]>

# %%
print(res.text)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# 	<!-- Google Tag Manager -->
# <script nonce="nyEVqVxvwdofCwXIsTVCbnfNVvlPCx5k">(function (w, d, s, l, i) {
# 		w[l] = w[l] || [];
# 		w[l].push({
# 			'gtm.start':
# 				new Date().getTime(), event: 'gtm.js'
# 		});
# 		var f = d.getElementsByTagName(s)[0],
# 			j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : '';
# 		j.async = true;
# 		j.src =
# 			'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
# 		f.parentNode.insertBefore(j, f);
# 	})(window, document, 'script', 'dataLayer', 'GTM-NVFPDWB');</script>
# <!-- End Google Tag Manager -->
# 	<title>Table Playground | Web Scraper Test Sites</title>
# 	<meta charset="utf-8">
# 	<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
#
# 	<meta name="keywords"
# 		  content="web scraping,Web Scraper,Chrome extension,Crawling,Cross platform scraper"/>
# 	<meta name="description"
# ...

# %%
soup = bs4.BeautifulSoup(res.text)

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <!-- Google Tag Manager -->
#   <script nonce="nyEVqVxvwdofCwXIsTVCbnfNVvlPCx5k">
#    (function (w, d, s, l, i) {
# 		w[l] = w[l] || [];
# 		w[l].push({
# 			'gtm.start':
# 				new Date().getTime(), event: 'gtm.js'
# 		});
# 		var f = d.getElementsByTagName(s)[0],
# 			j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : '';
# 		j.async = true;
# 		j.src =
# 			'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
# 		f.parentNode.insertBefore(j, f);
# 	})(window, document, 'script', 'dataLayer', 'GTM-NVFPDWB');
#   </script>
#   <!-- End Google Tag Manager -->
#   <title>
#    Table Playground | Web Scraper Test Sites
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="web scraping,Web Scraper,Chrome extension,Crawling,Cross platform scraper" name="keywords">
# ...

# %%
table_tags = soup.find_all('table')

# %%
tb = table_tags[0]

# %%
tb
# Out:
# <table class="table table-bordered">
# <thead>
# <tr>
# <th>#</th>
# <th>First Name</th>
# <th>Last Name</th>
# <th>Username</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>1</td>
# <td>Mark</td>
# <td>Otto</td>
# <td>@mdo</td>
# </tr>
# <tr>
# <td>2</td>
# <td>Jacob</td>
# <td>Thornton</td>
# <td>@fat</td>
# </tr>
# <tr>
# <td>3</td>
# <td>Larry</td>
# <td>the Bird</td>
# <td>@twitter</td>
# </tr>
# </tbody>
# </table>

# %%
table_data = []
# Head
thead = tb.find('thead')
row = []
for th in thead.find_all('th'):
    row.append(th.text)
# print(row)
table_data.append(row)

# Row
tbody = tb.find('tbody')
for tr in tbody.find_all('tr'):
    row = []
    for td in tr.find_all('td'):
        row.append(td.text)
    table_data.append(row)
table_data
# Out:
# [['#', 'First Name', 'Last Name', 'Username'],
#  ['1', 'Mark', 'Otto', '@mdo'],
#  ['2', 'Jacob', 'Thornton', '@fat'],
#  ['3', 'Larry', 'the Bird', '@twitter']]

# %%
table_data = []
header = True
for tb in soup.find_all('table'):
    table=[]
    thead = tb.thead
    tbody = tb.tbody

    if header == True:
        for tr in thead.find_all('tr'):
            row_data = []
            for th in tr.find_all('th'):
                row_data.append(th.text)
            table.append(row_data)
        header = False

    for tr in tbody.find_all('tr'):
        row_data = []
        for td in tr.find_all('td'):
            row_data.append(td.text)
        table.append(row_data)
    table_data.extend(table)

# %%
table_data
# Out:
# [['#', 'First Name', 'Last Name', 'Username'],
#  ['1', 'Mark', 'Otto', '@mdo'],
#  ['2', 'Jacob', 'Thornton', '@fat'],
#  ['3', 'Larry', 'the Bird', '@twitter'],
#  ['4', 'Harry', 'Potter', '@hp'],
#  ['5', 'John', 'Snow', '@dunno'],
#  ['6', 'Tim', 'Bean', '@timbean']]

# %%
with open('Data.csv','w') as file:
    for row in table_data:
        file.write(','.join(row)+'\n')

# %%
rows = soup.find_all('table')
ans = {}
head = rows[0].thead
body = rows[0].tbody
th=[]
for tr in body:
    print(tr,type(tr))
# Out:
#  <class 'bs4.element.NavigableString'>
# <tr>
# <td>1</td>
# <td>Mark</td>
# <td>Otto</td>
# <td>@mdo</td>
# </tr> <class 'bs4.element.Tag'>
#
#  <class 'bs4.element.NavigableString'>
# <tr>
# <td>2</td>
# <td>Jacob</td>
# <td>Thornton</td>
# <td>@fat</td>
# </tr> <class 'bs4.element.Tag'>
#
#  <class 'bs4.element.NavigableString'>
# <tr>
# <td>3</td>
# <td>Larry</td>
# <td>the Bird</td>
# <td>@twitter</td>
# </tr> <class 'bs4.element.Tag'>
#
#  <class 'bs4.element.NavigableString'>

# %%
res = requests.get('https://www.amazon.in/s?k=mobile&page=2')

# %%
res
# Out:
# <Response [503]>

# %%
res = requests.get('https://www.flipkart.com/search?q=mobile&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off')

# %%
res
# Out:
# <Response [200]>

# %%
print(res.text)
# Out:
# <!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.c48a12.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.066267.css"/> <meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><link rel="shortcut icon" href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57.png"/>
# ...

# %%
soup = bs4.BeautifulSoup(res.text)

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <link href="https://rukminim2.flixcart.com" rel="preconnect"/>
#   <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.c48a12.css" rel="stylesheet"/>
#   <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.066267.css" rel="stylesheet"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="102988293558" property="fb:page_id"/>
#   <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
#   <link href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/>
#   <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
#   <meta content="website" property="og:type"/>
#   <meta content="Flipkart.com" name="og_site_name" property="og:site_name"/>
# ...

# %%
soup.find_all('div',attrs={'class':'KzDlHZ'})
# Out:
# [<div class="KzDlHZ">Nokia 105 Classic with Charger</div>,
#  <div class="KzDlHZ">REDMI A3X (Ocean Green, 64 GB)</div>,
#  <div class="KzDlHZ">POCO C71 (Desert Gold, 128 GB)</div>,
#  <div class="KzDlHZ">IQOO Z10X 5G (Titanium, 128 GB)</div>,
#  <div class="KzDlHZ">Infinix Note 50s 5G+ (Titanium Grey, 128 GB)</div>,
#  <div class="KzDlHZ">Samsung Galaxy F05 (Twilight Blue, 64 GB)</div>,
#  <div class="KzDlHZ">POCO C71 (Cool Blue, 128 GB)</div>,
#  <div class="KzDlHZ">vivo T4 Lite 5G Charger in the Box (Titanium Gold, 128 GB)</div>,
#  <div class="KzDlHZ">POCO M6 Plus 5G (Ice Silver, 128 GB)</div>,
#  <div class="KzDlHZ">POCO C75 5G (Enchanted Green, 64 GB)</div>,
#  <div class="KzDlHZ">REDMI A5 (Pondicherry Blue, 128 GB)</div>,
#  <div class="KzDlHZ">POCO C75 5G (Aqua Bliss, 64 GB)</div>,
#  <div class="KzDlHZ">Nokia 130 Music Dual Sim, Music Player, Wireless FM Radio and Dedicated Music Buttons</div>,
# ...

# %%
soup.find_all('div',attrs={'class':'Nx9bqj _4b5DiR'})
# Out:
# [<div class="Nx9bqj _4b5DiR">₹998</div>,
#  <div class="Nx9bqj _4b5DiR">₹5,999</div>,
#  <div class="Nx9bqj _4b5DiR">₹6,999</div>,
#  <div class="Nx9bqj _4b5DiR">₹13,690</div>,
#  <div class="Nx9bqj _4b5DiR">₹14,999</div>,
#  <div class="Nx9bqj _4b5DiR">₹6,499</div>,
#  <div class="Nx9bqj _4b5DiR">₹6,999</div>,
#  <div class="Nx9bqj _4b5DiR">₹9,999</div>,
#  <div class="Nx9bqj _4b5DiR">₹10,080</div>,
#  <div class="Nx9bqj _4b5DiR">₹7,699</div>,
#  <div class="Nx9bqj _4b5DiR">₹7,499</div>,
#  <div class="Nx9bqj _4b5DiR">₹7,699</div>,
#  <div class="Nx9bqj _4b5DiR">₹1,749</div>,
#  <div class="Nx9bqj _4b5DiR">₹2,109</div>,
#  <div class="Nx9bqj _4b5DiR">₹12,999</div>,
#  <div class="Nx9bqj _4b5DiR">₹1,140</div>,
#  <div class="Nx9bqj _4b5DiR">₹5,999</div>,
#  <div class="Nx9bqj _4b5DiR">₹10,080</div>,
#  <div class="Nx9bqj _4b5DiR">₹1,349</div>,
#  <div class="Nx9bqj _4b5DiR">₹10,499</div>,
#  <div class="Nx9bqj _4b5DiR">₹6,499</div>,
#  <div class="Nx9bqj _4b5DiR">₹1,159</div>,
# ...

# %%
soup.find_all('div',attrs={'class':'tUxRFH'})
# Out:
# [<div class="tUxRFH"><a class="CGtC98" href="/nokia-105-classic-charger/p/itmce67f340bc3c1?pid=MOBGWZUWRM7SF3FH&amp;lid=LSTMOBGWZUWRM7SF3FHHURLMH&amp;marketplace=FLIPKART&amp;q=mobile&amp;store=tyy%2F4io&amp;srno=s_1_1&amp;otracker=search&amp;otracker1=search&amp;fm=organic&amp;iid=f4eb2bc1-47a3-4034-ba06-da33b568bd3d.MOBGWZUWRM7SF3FH.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=8s4hsumsao0000001751867252759&amp;qH=532c28d5412dd75b" rel="noopener noreferrer" target="_blank"><div class="Otbq5D"><div class="yPq5Io"><div><div class="_4WELSP" style="height:200px;width:200px"><img alt="Nokia 105 Classic with Charger" class="DByuf4" loading="eager" src="https://rukminim2.flixcart.com/image/312/312/xif0q/mobile/p/o/i/105-single-sim-keypad-mobile-phone-with-wireless-fm-radio-nokia-original-imah2xgc9z6cwcqv.jpeg?q=70"/></div></div></div><div class="qaR90o"><div class="A8uQAd"><span class="Lni97G"><label class="tJjCVx"><input class="vn9L2C" readonly="" type="checkbox"/><div class="XqNaEv"></div><
# ...

# %%
phones = soup.find_all('div',attrs={'class':'KzDlHZ'})
prices = soup.find_all('div',attrs={'class':'Nx9bqj _4b5DiR'})
for phone,price in zip(phones,prices):
    print(f'{phone.text}-{price.text}')
# Out:
# Nokia 105 Classic with Charger-₹998
# REDMI A3X (Ocean Green, 64 GB)-₹5,999
# POCO C71 (Desert Gold, 128 GB)-₹6,999
# IQOO Z10X 5G (Titanium, 128 GB)-₹13,690
# Infinix Note 50s 5G+ (Titanium Grey, 128 GB)-₹14,999
# Samsung Galaxy F05 (Twilight Blue, 64 GB)-₹6,499
# POCO C71 (Cool Blue, 128 GB)-₹6,999
# vivo T4 Lite 5G Charger in the Box (Titanium Gold, 128 GB)-₹9,999
# POCO M6 Plus 5G (Ice Silver, 128 GB)-₹10,080
# POCO C75 5G (Enchanted Green, 64 GB)-₹7,699
# REDMI A5 (Pondicherry Blue, 128 GB)-₹7,499
# POCO C75 5G (Aqua Bliss, 64 GB)-₹7,699
# Nokia 130 Music Dual Sim, Music Player, Wireless FM Radio and Dedicated Music Buttons-₹1,749
# Nokia 106 4G Keypad Mobile, Long-Lasting Battery, MicroSD Card Slot-₹2,109
# vivo T4 Lite 5G Charger in the Box (Prism Blue, 256 GB)-₹12,999
# Nokia 105 Single SIM, Keypad Mobile Phone with Wireless FM Radio-₹1,140
# REDMI A3X (Midnight Black, 64 GB)-₹5,999
# POCO M6 Plus 5G (Graphite Black, 128 GB)-₹10,080
# ...
